# %% [markdown]
# # Inheritance hierarchy of builtins that are types

# %%
import builtins
import collections
from typing import Iterable
import urllib

from graphviz import Digraph, Graph
from IPython.core.display import HTML
from typeguard import typechecked

# %% [markdown]
# <h2 style="font-size: 1.2rem">
#     Helpers for displaying graphs with accompanying GraphvizOnline links:
# </h2>

# %%
@typechecked
def make_hyperlink(url: str, inner_html: str) -> HTML:
    """Make a hyperlink that opens a page in a new browser tab when clicked."""
    style = 'font-size: 1.3rem; background-color: #f6f6f9'
    tag_attributes = f'href="{url}" target="_blank" style="{style}"'
    return HTML(f'<a {tag_attributes}>{inner_html}</a>')

# %%
@typechecked
def make_graphvizonline_link(graph: Graph | Digraph) -> HTML:
    """Make a Jupyter/IPython link to open a graph in GraphvizOnline."""
    quoted = urllib.parse.quote(str(graph))
    url = f'https://dreampuf.github.io/GraphvizOnline/#{quoted}'
    return make_hyperlink(url, 'Open in GraphvizOnline')

# %%
@typechecked
def display_with_link(graph: Graph | Digraph) -> None:
    """Display a graph in Jupyter/IPython, with a GraphvizOnline link added."""
    display(graph)  # This may need an import, if extracted to a .py file.
    display(make_graphvizonline_link(graph))

# %% [markdown]
# <h2 style="font-size: 1.2rem">
#     Finding the public built-in types and building their full inheritance tree:
# </h2>

# %%
@typechecked
def public_builtin_types() -> Iterable[type]:
    """Yield types in the builtins module that are intended for direct use."""
    names = (name for name in dir(builtins) if not name.startswith('_'))
    members = (getattr(builtins, name) for name in names)
    return (member for member in members if isinstance(member, type))

# %%
@typechecked
def build_graph() -> Digraph:
    """Build an inheritance-hierarchy graph of builtins that are types."""
    graph = Digraph()
    visited = set()
    queue = collections.deque()
    
    @typechecked
    def visit(node: type, **kwargs: str) -> None:
        visited.add(node)
        queue.append(node)
        graph.node(node.__name__, fontname='sans-serif', **kwargs)
        
    for class_ in (t for t in public_builtin_types() if t is not Warning):
        if class_ not in visited:
            visit(class_)

    while queue:
        child = queue.popleft()
        for parent in child.__bases__:
            if parent not in visited:
                visit(parent, fillcolor='lightgray', style='filled')
                
            graph.edge(parent.__name__, child.__name__)
    
    return graph

# %%
graph = build_graph()

# %% [markdown]
# <h2 style="font-size: 1.2rem">
#     Inheritance hierarchy drawing (levels preserved, so very wide):
# </h2>

# %%
graph.graph_attr['size'] = '60'
display_with_link(graph)
# Out:
# <a href="https://dreampuf.github.io/GraphvizOnline/#digraph%20%7B%0A%09graph%20%5Bsize%3D60%5D%0A%09ArithmeticError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09AssertionError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09AttributeError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09BaseException%20%5Bfontname%3D%22sans-serif%22%5D%0A%09BlockingIOError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09BrokenPipeError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09BufferError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09BytesWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ChildProcessError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ConnectionAbortedError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ConnectionError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ConnectionRefusedError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ConnectionResetError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09DeprecationWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09EOFError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09EncodingWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09OSError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09Exception%20%5Bfontname%3D%22sans-serif%22%5D%0A%09FileExistsError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09FileNotFoundError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09FloatingPointError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09FutureWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09GeneratorExit%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ImportError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ImportWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09IndentationError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09IndexError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09InterruptedError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09IsADirectoryError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09KeyError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09KeyboardInterrupt%20%5Bfontname%3D%22sans-serif%22%5D%0A%09LookupError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09MemoryError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ModuleNotFoundError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09NameError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09NotADirectoryError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09NotImplementedError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09OverflowError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09PendingDeprecationWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09PermissionError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ProcessLookupError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09RecursionError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ReferenceError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ResourceWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09RuntimeError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09RuntimeWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09StopAsyncIteration%20%5Bfontname%3D%22sans-serif%22%5D%0A%09StopIteration%20%5Bfontname%3D%22sans-serif%22%5D%0A%09SyntaxError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09SyntaxWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09SystemError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09SystemExit%20%5Bfontname%3D%22sans-serif%22%5D%0A%09TabError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09TimeoutError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09TypeError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09UnboundLocalError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09UnicodeDecodeError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09UnicodeEncodeError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09UnicodeError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09UnicodeTranslateError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09UnicodeWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09UserWarning%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ValueError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09ZeroDivisionError%20%5Bfontname%3D%22sans-serif%22%5D%0A%09bool%20%5Bfontname%3D%22sans-serif%22%5D%0A%09bytearray%20%5Bfontname%3D%22sans-serif%22%5D%0A%09bytes%20%5Bfontname%3D%22sans-serif%22%5D%0A%09classmethod%20%5Bfontname%3D%22sans-serif%22%5D%0A%09complex%20%5Bfontname%3D%22sans-serif%22%5D%0A%09dict%20%5Bfontname%3D%22sans-serif%22%5D%0A%09enum ...

# %% [markdown]
# <h2 style="font-size: 1.2rem">
#     Inheritance hierarchy drawing (staggered for viewing ease):
# </h2>

# %%
graph.graph_attr['size'] = '45'
display_with_link(graph.unflatten(stagger=9))
# Out:
# <a href="https://dreampuf.github.io/GraphvizOnline/#digraph%20%7B%0A%09graph%20%5Bsize%3D45%5D%3B%0A%09ArithmeticError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09FloatingPointError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ArithmeticError%20-%3E%20FloatingPointError%09%5Bminlen%3D1%5D%3B%0A%09OverflowError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ArithmeticError%20-%3E%20OverflowError%09%5Bminlen%3D2%5D%3B%0A%09ZeroDivisionError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ArithmeticError%20-%3E%20ZeroDivisionError%09%5Bminlen%3D3%5D%3B%0A%09AssertionError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09AttributeError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BaseException%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09Exception%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BaseException%20-%3E%20Exception%3B%0A%09GeneratorExit%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BaseException%20-%3E%20GeneratorExit%09%5Bminlen%3D1%5D%3B%0A%09KeyboardInterrupt%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BaseException%20-%3E%20KeyboardInterrupt%09%5Bminlen%3D2%5D%3B%0A%09SystemExit%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BaseException%20-%3E%20SystemExit%09%5Bminlen%3D3%5D%3B%0A%09BlockingIOError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BrokenPipeError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BufferError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09BytesWarning%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ChildProcessError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ConnectionAbortedError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ConnectionError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ConnectionError%20-%3E%20BrokenPipeError%09%5Bminlen%3D1%5D%3B%0A%09ConnectionError%20-%3E%20ConnectionAbortedError%09%5Bminlen%3D2%5D%3B%0A%09ConnectionRefusedError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ConnectionError%20-%3E%20ConnectionRefusedError%09%5Bminlen%3D3%5D%3B%0A%09ConnectionResetError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09ConnectionError%20-%3E%20ConnectionResetError%09%5Bminlen%3D4%5D%3B%0A%09DeprecationWarning%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09EOFError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09EncodingWarning%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20BlockingIOError%09%5Bminlen%3D1%5D%3B%0A%09OSError%20-%3E%20ChildProcessError%09%5Bminlen%3D2%5D%3B%0A%09OSError%20-%3E%20ConnectionError%3B%0A%09FileExistsError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20FileExistsError%09%5Bminlen%3D3%5D%3B%0A%09FileNotFoundError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20FileNotFoundError%09%5Bminlen%3D4%5D%3B%0A%09InterruptedError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20InterruptedError%09%5Bminlen%3D5%5D%3B%0A%09IsADirectoryError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20IsADirectoryError%09%5Bminlen%3D6%5D%3B%0A%09NotADirectoryError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20NotADirectoryError%09%5Bminlen%3D7%5D%3B%0A%09PermissionError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20PermissionError%09%5Bminlen%3D8%5D%3B%0A%09ProcessLookupError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20ProcessLookupError%09%5Bminlen%3D9%5D%3B%0A%09TimeoutError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09OSError%20-%3E%20TimeoutError%09%5Bminlen%3D1%5D%3B%0A%09Exception%20-%3E%20ArithmeticError%3B%0A%09Exception%20-%3E%20AssertionError%09%5Bminlen%3D1%5D%3B%0A%09Exception%20-%3E%20AttributeError%09%5Bminlen%3D2%5D%3B%0A%09Exception%20-%3E%20BufferError%09%5Bminlen%3D3%5D%3B%0A%09Exception%20-%3E%20EOFError%09%5Bminlen%3D4%5D%3B%0A%09Exception%20-%3E%20OSError%3B%0A%09ImportError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09Exception%20-%3E%20ImportError%3B%0A%09LookupError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09Exception%20-%3E%20LookupError%3B%0A%09MemoryError%09%5Bfontname%3D%22sans-serif%22%5D%3B%0A%09Exception%20-%3E%20MemoryError%09%5Bm ...
